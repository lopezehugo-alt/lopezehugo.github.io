# %% [markdown]
# <a href="https://colab.research.google.com/github/lopezehugo-alt/lopezehugo.github.io/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ==========================================
# # 🚀  DADOS PESSOAIS
#  ==========================================
#
#  👤 Nome: Hugo Lopes
#  📧 Email: lopezehugo@gmail.com
#  🔗 LinkedIn: linkedin.com/in/hugoelopes
#  📍 Localização: Goiânia – Goiás – Brasil
#
#  ==========================================
# # 🎯  OBJETIVO
#  ==========================================
#
#  **Aplicar experiência em Risco Online, Prevenção à Fraude Digital e Meios de Pagamento para fortalecer a segurança financeira e otimizar resultados comerciais.**
# #
#  *Foco em*:
#  * Redução de perdas
#  * Aumento da conversão de vendas
#  * Mitigação de riscos com base em dados (**data driven**)
#
#  ==========================================
# # 🛠️  HABILIDADES
#  ==========================================
#
# # 💻  HARD SKILLS
#  * **Risco & Prevenção à Fraude:** estratégias antifraude e cenários ostensivos
#  * **Análise de Dados:** metodologias data driven
#  * **SQL (SQL Server, MySQL):** extração e manipulação de dados
#  * **Ferramentas:** Clearsale, Vtex, Bureaus de Consulta, adquirentes de pagamento
#  * **Testes:** Teste A/B, métricas de performance
#  * **Power BI:** dashboards estratégicos
#  * **Metodologias Ágeis:** gestão de projetos e squads
#
# # 🤝  SOFT SKILLS
#  * Visão Analítica e Crítica
#  * Comunicação clara (níveis técnicos e executivos)
#  * Gestão de Risco em cenários críticos
#  * Colaboração e liderança de equipes
#  * Resiliência e proatividade
#
#  ==========================================
# # 📄 . BREVE DESCRIÇÃO
#  ==========================================
#
#  Profissional com experiência em **Risco Online, Prevenção à Fraude Digital e Meios de Pagamento**, atuando para recuperação de receita, mitigação de perdas e aumento de conversão de vendas.
#
# # **Diferenciais:**
#  * Aplicação de metodologias ágeis
#  * Uso de dados para decisões estratégicas
#  * Integração de ferramentas de mercado (Clearsale, Vtex, SQL, Power BI)
#  * União de análise técnica + visão comercial + segurança
#
#  Combinação de **hard skills (dados e risco)** com **soft skills (comunicação, visão crítica e gestão de tempo)**, garantindo crescimento seguro e sustentável para empresas.

# %% [markdown]
# ## **INTRODUÇÃO PYTHON**
# # Primeiros Passos com Python: Do Básico a Bibliotecas Essenciais
#
# Este notebook foi criado para guiar você pelos fundamentos da linguagem de programação Python, desde a sintaxe básica até o uso de bibliotecas poderosas para análise de dados.
#
# # 1. Introdução ao Python
#
# Python é uma linguagem de programação versátil e fácil de aprender, conhecida por sua sintaxe clara e legível. É amplamente utilizada em diversas áreas, como desenvolvimento web, inteligência artificial, ciência de dados e automação.
#
# ##### 1.1 Hello, World!
#
# O "Hello, World!" é a primeira linha de código que a maioria dos programadores aprende. Ele simplesmente imprime uma mensagem na tela.

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# #### 1.2 Variáveis e Tipos de Dados
#
# Variáveis são como "caixas" que armazenam valores. Python é uma linguagem de tipagem dinâmica, o que significa que você não precisa declarar o tipo da variável.
#
# ##### Célula de Código: Exemplo de Variáveis

# %%
# Variável do tipo string (texto)
nome = "Maria"

# Variável do tipo integer (número inteiro)
idade = 30

# Variável do tipo float (número com casas decimais)
altura = 1.65

# Variável do tipo boolean (Verdadeiro ou Falso)
estudante = True

print(f"Nome: {nome}, Idade: {idade}, Altura: {altura}, Estudante: {estudante}")
# Out:
# Nome: Maria, Idade: 30, Altura: 1.65, Estudante: True

# %% [markdown]
# #2. Estruturas de Dados
#
# Python oferece diversas estruturas de dados integradas para organizar informações. As mais comuns são listas, tuplas e dicionários.
#
# 2.1 Listas
#
# Listas são coleções ordenadas e mutáveis (você pode alterar os itens) de dados.
#
# Célula de Código: Manipulando uma Lista

# %%
frutas = ["maçã", "banana", "laranja"]

# Adicionando um item
frutas.append("uva")
print("Lista após adicionar uva:", frutas)

# Acessando um item pelo índice (começa em 0)
primeira_fruta = frutas[0]
print("Primeira fruta:", primeira_fruta)

# Removendo um item
frutas.remove("banana")
print("Lista após remover banana:", frutas)
# Out:
# Lista após adicionar uva: ['maçã', 'banana', 'laranja', 'uva']
# Primeira fruta: maçã
# Lista após remover banana: ['maçã', 'laranja', 'uva']

# %% [markdown]
# #3. Estruturas de Controle
#
# Estruturas de controle permitem que você decida qual código deve ser executado, como laços de repetição e condicionais.
#
# 3.1 Laços de Repetição (for loop)
# O for loop é usado para iterar sobre uma sequência (como uma lista).
#
# Célula de Código: for loop em uma lista

# %%
numeros = [1, 2, 3, 4, 5]

print("Contando...")
for numero in numeros:
    print(numero)
# Out:
# Contando...
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # 4. Bibliotecas Essenciais para Análise de Dados
#
# A verdadeira força do Python para ciência de dados e análise de dados reside em suas bibliotecas. Duas das mais importantes são NumPy e Pandas.
#
# 4.1 NumPy (Numerical Python)
# NumPy é fundamental para computação numérica em Python. Ele fornece um objeto array multidimensional de alto desempenho e ferramentas para trabalhar com esses arrays.
#
# Célula de Código: Exemplo com NumPy

# %%
import numpy as np

# Criando um array
array_np = np.array([10, 20, 30, 40, 50])
print("Array NumPy:", array_np)

# Operações matemáticas de forma eficiente
array_multiplicado = array_np * 2
print("Array multiplicado por 2:", array_multiplicado)

# Criando uma matriz
matriz = np.array([[1, 2], [3, 4]])
print("\nMatriz NumPy:\n", matriz)
# Out:
# Array NumPy: [10 20 30 40 50]
# Array multiplicado por 2: [ 20  40  60  80 100]
#
# Matriz NumPy:
#  [[1 2]
#  [3 4]]

# %% [markdown]
# * Explicação do Código NumPy
#
# Este código demonstra os fundamentos da biblioteca NumPy, que é a base para a computação numérica em Python. Ele se destaca por sua eficiência em lidar com grandes volumes de dados de forma mais rápida que as listas tradicionais do Python.
#
# * Entendendo o Array NumPy
#
# Primeiro, a biblioteca é importada e apelidada de np, uma convenção padrão e amplamente adotada na comunidade de programação. Em seguida, um array NumPy é criado a partir de uma lista de números. Um array é uma grade de valores, todos do mesmo tipo. Essa estrutura de dados é o ponto central da biblioteca, sendo muito mais eficiente para operações matemáticas do que as listas nativas do Python.
#
# * Operações Matemáticas Eficientes
#
# A grande diferença do NumPy é a forma como ele realiza operações matemáticas. Em vez de percorrer cada item para multiplicá-lo, por exemplo, ele executa a operação em todos os elementos do array de uma só vez, de forma vetorizada. Isso é extremamente rápido, especialmente ao lidar com grandes conjuntos de dados. O resultado é um novo array onde cada número foi multiplicado pelo valor desejado.
#
# * Trabalhando com Matrizes
#
# A capacidade do NumPy de trabalhar com múltiplas dimensões é o que o torna tão poderoso. O código demonstra a criação de uma matriz 2x2 (duas linhas e duas colunas). Esse tipo de estrutura é fundamental para tarefas de álgebra linear, ciência de dados e machine learning, permitindo que você represente dados complexos de forma organizada e eficiente para realizar cálculos avançados.

# %% [markdown]
# 4.2 Pandas
#
# Pandas é a biblioteca de fato para manipulação e análise de dados. Sua principal estrutura de dados, o DataFrame, é ideal para trabalhar com dados tabulares (como planilhas do Excel ou tabelas de bancos de dados).
#
# Célula de Código: Exemplo com Pandas

# %%
import pandas as pd

# Criando um dicionário com dados
dados = {
    'Nome': ['João', 'Maria', 'Pedro', 'Ana'],
    'Idade': [25, 30, 35, 28],
    'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'São Paulo']
}

# Criando um DataFrame a partir do dicionário
df = pd.DataFrame(dados)

print("DataFrame criado:\n", df)

# Filtrando dados: pessoas com mais de 30 anos
df_filtrado = df[df['Idade'] > 30]
print("\nPessoas com mais de 30 anos:\n", df_filtrado)

# Calculando a média da idade
media_idade = df['Idade'].mean()
print(f"\nMédia de idade: {media_idade:.2f}")
# Out:
# DataFrame criado:
#      Nome  Idade          Cidade
# 0   João     25       São Paulo
# 1  Maria     30  Rio de Janeiro
# 2  Pedro     35  Belo Horizonte
# 3    Ana     28       São Paulo
#
# Pessoas com mais de 30 anos:
#      Nome  Idade          Cidade
# 2  Pedro     35  Belo Horizonte
#
# Média de idade: 29.50

# %% [markdown]
# * Explicação do Código Pandas (Exemplo Básico)
#
# Este código é um ótimo ponto de partida para entender como a biblioteca Pandas funciona, a principal ferramenta para análise de dados em Python. Ele demonstra como criar e manipular uma das suas estruturas de dados mais importantes: o DataFrame.
#
# * Construindo o DataFrame
#
# Primeiro, a biblioteca Pandas é importada com o apelido pd. Em seguida, um dicionário em Python é criado para armazenar os dados. As chaves do dicionário (como 'Nome' e 'Idade') se tornam os nomes das colunas, enquanto as listas de valores se tornam as linhas do DataFrame.
#
# A linha mais importante é onde o DataFrame é de fato criado a partir desse dicionário. O DataFrame se assemelha a uma tabela ou planilha, com linhas e colunas, tornando a organização e a manipulação de dados muito mais intuitiva.
#
# * Filtragem e Seleção de Dados
#
# Uma das capacidades mais úteis do Pandas é a filtragem de dados. No exemplo, uma condição é usada para selecionar apenas as pessoas com mais de 30 anos. O Pandas avalia essa condição linha por linha, retornando True ou False para cada uma. Em seguida, ele usa essa série de valores para "filtrar" o DataFrame original, exibindo apenas as linhas onde a condição foi True. Isso permite que você trabalhe com subconjuntos específicos dos seus dados de forma simples e rápida.
#
# * Realizando Cálculos
#
# Por fim, o código mostra como é fácil realizar cálculos básicos. Ao acessar a coluna 'Idade', podemos usar o método .mean() para calcular a média de todos os valores na coluna. O Pandas possui uma vasta gama de métodos estatísticos integrados, como .sum(), .min(), .max(), entre outros, que podem ser aplicados diretamente em colunas inteiras, eliminando a necessidade de escrever loops complexos.

# %% [markdown]
#  # 5: Interagindo com o Usuário
#
# Com os conceitos de variáveis e print() que você já conhece, é fácil criar programas que se comunicam com o usuário, pedindo informações e usando-as para dar uma resposta. Para isso, usamos a função input().
#
# A função input() exibe uma mensagem para o usuário e espera que ele digite algo. O valor que o usuário digita é então armazenado em uma variável. É importante lembrar que o input() sempre retorna uma string, então, se você precisar de um número (como no caso da idade), terá que converter o valor.
#
# Célula de Código: Formulário Simples

# %%
# 1. Solicitando o nome ao usuário
# A função input() retorna o texto digitado pelo usuário.
nome = input("Por favor, digite seu nome: ")

# 2. Solicitando a idade e convertendo o valor para um número inteiro (int)
# O input() sempre retorna uma string, então é necessário a conversão.
# Usamos int() para converter a string de idade para um número.
idade_str = input("Qual a sua idade? ")
idade = int(idade_str)

# 3. Exibindo uma mensagem personalizada de saudação
# Usamos uma f-string para inserir a variável 'nome' diretamente na frase.
print(f"Olá, {nome}! Bem-vindo(a)!")

# 4. Criando um retorno com base na idade
# Usamos uma estrutura condicional 'if/else' para dar uma resposta diferente.
if idade >= 18:
    print("Você já pode dirigir!")
else:
    print("Você ainda não pode dirigir, mas logo chegará a sua vez!")

# 5. Calculando e exibindo o ano de nascimento aproximado
# A data atual é fixa para simplificar o exemplo, mas você poderia usar bibliotecas para obter o ano atual.
ano_atual = 2025
ano_nascimento = ano_atual - idade
print(f"Seu ano de nascimento aproximado é: {ano_nascimento}")
# Out:
# Por favor, digite seu nome: Hugo
# Qual a sua idade? 26
# Olá, Hugo! Bem-vindo(a)!
# Você já pode dirigir!
# Seu ano de nascimento aproximado é: 1999

# %% [markdown]
# # 6. Visualização de Dados com Matplotlib
#
# Matplotlib é a biblioteca de visualização de dados mais popular em Python. Ela é versátil e permite a criação de uma vasta gama de gráficos, desde os mais simples até os mais complexos. Para começar, vamos criar um gráfico de barras bem simples para visualizar a quantidade de produtos vendidos por região, utilizando os dados da nossa análise anterior.
#
# Preparando o Ambiente
# Primeiro, precisamos importar a biblioteca matplotlib.pyplot, que é o módulo mais usado para plotar gráficos.

# %%
import matplotlib.pyplot as plt

# %%
# Supondo que você já tem o DataFrame 'df' do exemplo anterior
# Se não, rode o seguinte código para criá-lo:
import pandas as pd
import io
dados_csv = """ID_Venda,Produto,Preco,Quantidade,Data,Regiao,Status
101,Smartphone X,1200.00,1,2023-01-05,Norte,Entregue
102,Notebook Y,2500.00,1,2023-01-06,Sul,Cancelada
103,Fone de Ouvido Z,250.00,2,2023-01-07,Norte,Entregue
104,Smartphone X,1200.00,1,2023-01-08,Leste,Entregue
105,Notebook Y,2500.00,1,2023-01-09,Oeste,Entregue
106,Fone de Ouvido Z,250.00,1,2023-01-10,Norte,Entregue
107,Smartphone X,1200.00,1,2023-01-11,Leste,Entregue
108,Notebook Y,2500.00,1,2023-01-12,Sul,Entregue
109,Fone de Ouvido Z,250.00,3,2023-01-13,Oeste,Entregue
110,Notebook Y,2500.00,1,2023-01-14,Sul,Entregue"""
df = pd.read_csv(io.StringIO(dados_csv))

# Contando o número de vendas (transações) por região
vendas_por_regiao = df['Regiao'].value_counts()

# Criando o gráfico
plt.figure(figsize=(8, 6)) # Define o tamanho da figura (opcional)
vendas_por_regiao.plot(kind='bar')

# Adicionando títulos e rótulos
plt.title('Vendas Totais por Região')
plt.xlabel('Região')
plt.ylabel('Número de Vendas')
plt.xticks(rotation=45) # Rotaciona os rótulos do eixo X para melhor visualização
plt.grid(axis='y', linestyle='--') # Adiciona linhas de grade no eixo Y

# Mostrando o gráfico
plt.show()

# %% [markdown]
# Entendendo o Código
#
# * vendas_por_regiao = df['Regiao'].value_counts(): Primeiro, usamos o Pandas para contar a ocorrência de cada região em nossa coluna 'Regiao'. Isso nos dá uma série de dados pronta para ser plotada.
#
# * plt.figure(figsize=(8, 6)): Esta linha cria uma "tela" para o nosso gráfico e define o seu tamanho.
#
# * vendas_por_regiao.plot(kind='bar'): Esta é a maneira mais simples de plotar usando o Pandas e o Matplotlib. O kind='bar' especifica que queremos um gráfico de barras.
#
# * plt.title(), plt.xlabel(), plt.ylabel(): Funções para adicionar o título do gráfico e os rótulos dos eixos. É sempre uma boa prática rotular seus gráficos para que sejam claros e fáceis de entender.
#
# * plt.xticks(rotation=45): Rotaciona os nomes das regiões para evitar que se sobreponham.
#
# * plt.show(): Por fim, esta função exibe o gráfico na tela.

# %% [markdown]
# # Estudo de Caso
#
#  * Análise de Chargeback em E-commerce
#
# Este notebook simula um cenário de análise de dados de vendas, focando em transações que resultaram em chargeback (fraude). Utilizaremos as bibliotecas Pandas para manipulação e análise dos dados e Matplotlib para a visualização dos resultados.
#
#  ▶ Preparação do Ambiente e Criação da Base de Dados
#
# Primeiro, vamos importar as bibliotecas necessárias e criar nossa base de dados fictícia. Os dados serão gerados de forma aleatória para simular um cenário real.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from datetime import datetime

# Definindo listas de dados para a simulação
nomes = ['João', 'Maria', 'Pedro', 'Ana', 'Carlos', 'Sofia', 'Lucas', 'Laura', 'Gabriel', 'Isabela']
estados = ['SP', 'RJ', 'MG', 'RS', 'SC']
incidentes = ['Chargeback', 'Venda Aceita']
meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho']
bandeiras = ['Visa', 'Mastercard', 'Elo', 'Amex']
produtos = ['Smartphone X', 'Notebook Pro', 'Fone Bluetooth', 'Smartwatch', 'Câmera']

# Criando a base de dados
# Usaremos um dicionário para gerar os dados aleatórios
base_dados = {
    'Nome': [random.choice(nomes) for _ in range(1000)],
    'Idade': [random.randint(18, 60) for _ in range(1000)],
    'UF': [random.choice(estados) for _ in range(1000)],
    'Valor_Transacao': [round(random.uniform(50, 5000), 2) for _ in range(1000)],
    'Incidente': [random.choice(incidentes) for _ in range(1000)],
    'Mes': [random.choice(meses) for _ in range(1000)],
    'Bandeira_Cartao': [random.choice(bandeiras) for _ in range(1000)],
    'Produto': [random.choice(produtos) for _ in range(1000)],
}

# Criando o DataFrame
df = pd.DataFrame(base_dados)

# Criando uma amostra de chargebacks para a análise
# Isso garante que teremos dados para analisar
chargebacks = df.sample(n=100)
chargebacks['Incidente'] = 'Chargeback'
df.update(chargebacks)

print("Amostra do DataFrame criado:")
print(df.head())
print("\nInformações do DataFrame:")
df.info()
# Out:
# Amostra do DataFrame criado:
#      Nome  Idade  UF  Valor_Transacao     Incidente        Mes  \
# 0  Carlos     51  SP          4526.65  Venda Aceita      Abril
# 1   Laura     35  MG            85.80  Venda Aceita  Fevereiro
# 2   Lucas     39  SC          1139.88    Chargeback      Abril
# 3   Maria     20  SC          3743.50    Chargeback       Maio
# 4  Carlos     40  RJ          3924.27    Chargeback    Janeiro
#
#   Bandeira_Cartao         Produto
# 0            Amex    Smartphone X
# 1             Elo          Câmera
# 2             Elo  Fone Bluetooth
# 3            Visa  Fone Bluetooth
# 4             Elo          Câmera
#
# Informações do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nome             1000 non-null   object
#  1   Idade            1000 non-null   int64
# ...

# %% [markdown]
#  ▶ Análise dos Dados de Chargeback
#
# Agora, vamos filtrar o DataFrame para analisar apenas as transações que tiveram um chargeback. A partir deste novo DataFrame, responderemos às perguntas da nossa análise.
#
#  ▶ Idade Média dos Fraudadores

# %%
# Filtrando o DataFrame para transações com chargeback
df_chargeback = df[df['Incidente'] == 'Chargeback']

# Calculando a idade média
idade_media_chargeback = df_chargeback['Idade'].mean()

print(f"A idade média das pessoas envolvidas em chargeback é: {idade_media_chargeback:.2f} anos")
# Out:
# A idade média das pessoas envolvidas em chargeback é: 38.54 anos

# %% [markdown]
#  ▶ Estados com Maiores Concentrações de Chargeback

# %%
# Contando a quantidade de chargebacks por estado
chargebacks_por_uf = df_chargeback['UF'].value_counts()

print("Estados com a maior quantidade de chargebacks:")
print(chargebacks_por_uf)

# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
chargebacks_por_uf.plot(kind='bar', color='skyblue')
plt.title('Concentração de Chargebacks por UF')
plt.xlabel('Estado (UF)')
plt.ylabel('Número de Chargebacks')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# Estados com a maior quantidade de chargebacks:
# UF
# RJ    128
# MG    119
# SC    112
# RS    100
# SP     94
# Name: count, dtype: int64

# %% [markdown]
#  ▶ Produtos Mais Afetados

# %%
# Contando a quantidade de chargebacks por produto
chargebacks_por_produto = df_chargeback['Produto'].value_counts()

print("Produtos mais afetados por chargeback:")
print(chargebacks_por_produto)

# Criando o gráfico de barras
plt.figure(figsize=(12, 7))
chargebacks_por_produto.plot(kind='bar', color='salmon')
plt.title('Produtos Mais Afetados por Chargeback')
plt.xlabel('Produto')
plt.ylabel('Número de Chargebacks')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# Produtos mais afetados por chargeback:
# Produto
# Notebook Pro      129
# Fone Bluetooth    110
# Câmera            106
# Smartphone X      105
# Smartwatch        103
# Name: count, dtype: int64

# %% [markdown]
#  ▶ Análise Temporal: Vendas e Perdas por Mês

# %%
# Agrupando por mês para contar o número de incidentes
incidente_por_mes = df.groupby(['Mes', 'Incidente']).size().unstack(fill_value=0)

# Reordenando os meses para a ordem correta
ordem_meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho']
incidente_por_mes = incidente_por_mes.reindex(ordem_meses)

print("Distribuição de incidentes por mês:")
print(incidente_por_mes)

# Criando o gráfico de barras agrupadas
incidente_por_mes.plot(kind='bar', figsize=(12, 7))
plt.title('Análise Temporal de Incidentes por Mês')
plt.xlabel('Mês')
plt.ylabel('Número de Transações')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# Distribuição de incidentes por mês:
# Incidente  Chargeback  Venda Aceita
# Mes
# Janeiro            85            65
# Fevereiro         113            81
# Março             101            69
# Abril              90            81
# Maio               76            80
# Junho              88            71

# %% [markdown]
#  ▶ Valor de Perda por Mês

# %%
# Agrupando por mês e somando o valor das transações com chargeback
perda_por_mes = df_chargeback.groupby('Mes')['Valor_Transacao'].sum()

# Reordenando os meses
perda_por_mes = perda_por_mes.reindex(ordem_meses, fill_value=0)

print("Valor de perda por mês devido a chargeback:")
print(perda_por_mes)

# Criando o gráfico de linha
plt.figure(figsize=(12, 7))
perda_por_mes.plot(kind='line', marker='o', color='red', linestyle='--')
plt.title('Valor Total de Perda por Mês (Chargeback)')
plt.xlabel('Mês')
plt.ylabel('Valor de Perda (R$)')
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# Valor de perda por mês devido a chargeback:
# Mes
# Janeiro      200712.05
# Fevereiro    258361.00
# Março        248646.05
# Abril        232520.00
# Maio         206234.62
# Junho        200230.50
# Name: Valor_Transacao, dtype: float64

# %% [markdown]
#  ▶ Bandeiras de Cartão Mais Afetadas

# %%
# Contando a quantidade de chargebacks por bandeira
chargebacks_por_bandeira = df_chargeback['Bandeira_Cartao'].value_counts()

print("Bandeiras de cartão mais afetadas por chargeback:")
print(chargebacks_por_bandeira)

# Criando o gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(chargebacks_por_bandeira, labels=chargebacks_por_bandeira.index, autopct='%1.1f%%', startangle=140, colors=['gold', 'lightcoral', 'lightskyblue', 'lightgreen'])
plt.title('Distribuição de Chargebacks por Bandeira de Cartão')
plt.show()
# Out:
# Bandeiras de cartão mais afetadas por chargeback:
# Bandeira_Cartao
# Visa          150
# Amex          148
# Elo           138
# Mastercard    117
# Name: count, dtype: int64

# %% [markdown]
#  ▶ Conclusão
# Através deste exercício, pudemos simular uma análise real de dados de e-commerce e identificar padrões de fraude. Utilizamos Pandas para processar e resumir os dados e Matplotlib para visualizá-los, o que nos permitiu identificar rapidamente:
#
# A idade média dos envolvidos.
#
# Os estados e produtos mais vulneráveis.
#
# A perda financeira por período.
#
# A distribuição de fraudes entre as bandeiras de cartão.

# %% [markdown]
# # Analise Descritiva de uma base CSV Publica, pertinente da kaggle:

# %%
from google.colab import files
import pandas as pd

# Upload do arquivo
uploaded = files.upload()

# O nome do arquivo uploaded será a chave no dicionário 'uploaded'
file_name = "balanced_ai_human_prompts.csv"

# Verificando se o arquivo foi carregado
if file_name in uploaded:
  print(f"Arquivo '{file_name}' carregado com sucesso!")

  # Lendo o arquivo CSV com pandas
  df = pd.read_csv(file_name)

  # Exibindo as primeiras linhas do DataFrame para confirmar o upload
  print(df.head())

else:
  print(f"Erro: O arquivo '{file_name}' não foi encontrado. Verifique o nome do arquivo.")
# Out:
#      <input type="file" id="files-c4af267b-ef5f-4aa9-948b-f881e18a65da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4af267b-ef5f-4aa9-948b-f881e18a65da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# * Verificando as Primeiras Linhas e Informações Gerais
# É sempre bom começar inspecionando o cabeçalho e as colunas do seu DataFrame.

# %%
# Mostra as primeiras 5 linhas do DataFrame
print("Primeiras 5 linhas do DataFrame:")
print(df.head())

# Mostra as últimas 5 linhas
print("\nÚltimas 5 linhas do DataFrame:")
print(df.tail())

# Exibe informações sobre o DataFrame, como o tipo de dado de cada coluna e a quantidade de valores não-nulos
print("\nInformações sobre o DataFrame:")
df.info()
# Out:
# Primeiras 5 linhas do DataFrame:
#                                                 text  generated
# 0  Machine learning, a subset of artificial intel...          1
# 1  A decision tree, a prominent machine learning ...          1
# 2  Education, a cornerstone of societal progress,...          1
# 3  Computers, the backbone of modern technology, ...          1
# 4  Chess, a timeless game of strategy and intelle...          1
#
# Últimas 5 linhas do DataFrame:
#                                                    text  generated
# 2745  Generate a detailed summary of global healthca...          1
# 2746  Compose an in-depth exploration of financial t...          1
# 2747  Generate a detailed summary of autonomous vehi...          1
# 2748  Develop a persuasive argument about internet o...          1
# 2749  Generate a detailed summary of supply chain ma...          1
#
# Informações sobre o DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2750 entries, 0 to 2749
# ...

# %% [markdown]
# * Resumo Estatístico das Colunas Numéricas

# %%
print("\nResumo estatístico das colunas numéricas:")
print(df.describe())
# Out:
# Resumo estatístico das colunas numéricas:
#          generated
# count  2750.000000
# mean      0.500000
# std       0.500091
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# * Análise da Distribuição dos Dados
# A coluna generated é o ponto central. Ela é categórica e binária (0 e 1, onde 1 provavelmente significa "gerado por IA" e 0 significa "criado por humano").

# %%
print("Contagem de prompts por categoria (IA vs. Humano):")
print(df['generated'].value_counts())
# Out:
# Contagem de prompts por categoria (IA vs. Humano):
# generated
# 1    1375
# 0    1375
# Name: count, dtype: int64

# %% [markdown]
# * Análise da Coluna de Texto (text)
# A coluna text contém os prompts em si. Podemos extrair informações valiosas dela.
#
# Comprimento dos Prompts: Existe diferença no tamanho dos prompts gerados por IA versus os criados por humanos?

# %%
# Criando uma nova coluna com o comprimento de cada prompt
df['text_length'] = df['text'].apply(len)

# Análise estatística do comprimento
print("\nAnálise do comprimento do texto por categoria:")
print(df.groupby('generated')['text_length'].describe())
# Out:
# Análise do comprimento do texto por categoria:
#             count         mean         std     min     25%     50%     75%  \
# generated
# 0          1375.0  3172.581091  918.439217  1486.0  2556.5  2987.0  3624.5
# 1          1375.0   169.264727  342.692562    78.0    90.0    95.0   100.0
#
#               max
# generated
# 0          8436.0
# 1          2290.0

# %% [markdown]
# o mínimo e o máximo de caracteres para cada categoria (generated=0 e generated=1). Uma diferença significativa pode indicar um padrão.

# %% [markdown]
# * Análise de Vocabulário: Podemos analisar a riqueza do vocabulário. A quantidade de palavras únicas ou a média de palavras por frase pode variar entre os dois grupos.
#
# * Nuvem de Palavras: Uma nuvem de palavras visualiza as palavras mais frequentes em cada categoria. Isso pode revelar tópicos ou termos mais comuns em prompts de IA ou de humanos.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Juntando todos os textos de cada categoria
text_ia = " ".join(review for review in df[df['generated']==1].text)
text_humano = " ".join(review for review in df[df['generated']==0].text)

# Gerando as nuvens de palavras
wordcloud_ia = WordCloud(width=800, height=400, background_color="white").generate(text_ia)
wordcloud_humano = WordCloud(width=800, height=400, background_color="white").generate(text_humano)

# Plotando as nuvens
plt.figure(figsize=(15, 7))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_ia, interpolation='bilinear')
plt.axis("off")
plt.title("Palavras Mais Comuns (Geradas por IA)")

plt.subplot(1, 2, 2)
plt.imshow(wordcloud_humano, interpolation='bilinear')
plt.axis("off")
plt.title("Palavras Mais Comuns (Criadas por Humanos)")

plt.show()

# %% [markdown]
# # Conclusão
#
#
# *Analisar dados com Python, usando bibliotecas como pandas, é uma ferramenta extremamente poderosa. Ao integrar essa capacidade com a assistência de uma IA, como a que estou fazendo, o processo se torna ainda mais eficiente e dinâmico.*
#
# *A verdadeira força dessa combinação está em:*
#
# *Aceleração do Fluxo de Trabalho: Você não precisa memorizar cada sintaxe ou função. A IA pode gerar o código rapidamente, permitindo que você se concentre na lógica da análise e nos insights, em vez de passar tempo procurando a documentação.*
#
# *Aprendizado Contínuo: Ao receber o código e a explicação, você entende o porquê de cada etapa. Isso não apenas resolve o problema imediato, mas também expande seu conhecimento sobre as bibliotecas de Python e as técnicas de análise de dados.*
#
# *Exploração de Novas Perspectivas: Com a IA, é fácil testar diferentes abordagens. Em vez de se prender a uma única ideia, você pode pedir sugestões para novas análises (como a nuvem de palavras que sugeri) e explorar os dados de maneiras que talvez não tivesse pensado sozinho.*
#
# *Em resumo, a combinação de Python e IA transforma a análise de dados de uma tarefa manual e técnica em um processo de descoberta colaborativo e estratégico. É uma parceria que potencializa suas habilidades e acelera a obtenção de insights valiosos.*
